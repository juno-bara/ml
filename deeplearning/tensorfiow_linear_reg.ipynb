# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt


# 가상적인 데이터 생성
X = data = np.linspace(1,2,200) # 시작값=1, 종료값=2, 개수=200
y = X*4 + np.random.randn(200) * 0.3 # x를 4배로 하고 편차 0.3정도의


# 가우시안 잡음추가
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim=1, activation='linear'))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.fit(X, y, batch_size=1, epochs=30)
predict = model.predict(data)



plt.plot(data, predict, 'b', data, y, 'k.') # 첫 번째 그래프는 파란색 마커로
plt.show()
# Out:
# Epoch 1/30
# 200/200 [==============================] - 1s 3ms/step - loss: 2.8654 - mse: 2.8654
# Epoch 2/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2918 - mse: 0.2918
# Epoch 3/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2591 - mse: 0.2591
# Epoch 4/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2278 - mse: 0.2278
# Epoch 5/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2044 - mse: 0.2044
# Epoch 6/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1899 - mse: 0.1899
# Epoch 7/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1711 - mse: 0.1711
# Epoch 8/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1569 - mse: 0.1569
# Epoch 9/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1532 - mse: 0.1532
# Epoch 10/30
# 200/200 [==============================] - 1s 3ms/step - loss: 0.1449 - mse: 0.1449
# ...

# %%
from sklearn.linear_model import LinearRegression

X = data = np.linspace(1,2,200)
y = X*4 + np.random.randn(200)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=156)

li_reg = LinearRegression()

li_reg.fit(x_train.reshape(-1,1),y_train)
li_reg_pred = li_reg.predict(x_test.reshape(-1,1))

from sklearn.metrics import mean_squared_error

import numpy as np
mse = mean_squared_error(y_test,li_reg_pred)
print(mse, np.sqrt(mse))
# Out:
# 1.1249855163409959 1.0606533440955135

# %%
x = data = np.linspace(1,2,200)
y = X*4 + np.random.randn(200)

li_reg.fit(x.reshape(-1,1),y)
pred = li_reg.predict(x.reshape(-1,1))
mse = mean_squared_error(y,x)
print(mse)
print(li_reg.coef_)
# Out:
# 21.318552984560643
# [3.74863411]

# %%
X[:10]
# Out:
# array([1.        , 1.00502513, 1.01005025, 1.01507538, 1.0201005 ,
#        1.02512563, 1.03015075, 1.03517588, 1.04020101, 1.04522613])

# %%
y[:10]
# Out:
# array([3.08460801, 4.39401033, 4.22396509, 3.85474675, 5.13050522,
#        3.57991207, 5.38754226, 4.93252241, 2.92360346, 5.49958629])

# %%
x_data = np.array(x)
y_data = np.array(y)

a = 0
b = 0

lr = 0.03

epochs = 2023

for i in range(epochs):
    y_hat = a * x_data + b
    error = y_data + y_hat
    a_diff = -(2/len(x_data)) * sum(x_data * (error))
    b_diff = -(2/len(x_data)) * sum(x_data)
    a = a - lr * a_diff
    b = b - lr * b_diff
    if i % 500 == 0:
        print("epochs : ", i, "기울기 : ", a, "절편 = " ,b  )
# Out:
# epochs :  0 기울기 :  0.5528658321694648 절편 =  0.09
# epochs :  500 기울기 :  1.440346282834892e+29 절편 =  45.09000000000045
# epochs :  1000 기울기 :  4.1731522987730435e+57 절편 =  90.09000000000215
# epochs :  1500 기울기 :  1.2090981395444774e+86 절편 =  135.09000000000384
# epochs :  2000 기울기 :  3.503151110683739e+114 절편 =  180.09000000000555

# %%
np.sqrt(error**2)
# Out:
# array([5.49367241e+115, 5.52127880e+115, 5.54888520e+115, 5.57649159e+115,
#        5.60409799e+115, 5.63170438e+115, 5.65931077e+115, 5.68691717e+115,
#        5.71452356e+115, 5.74212996e+115, 5.76973635e+115, 5.79734274e+115,
#        5.82494914e+115, 5.85255553e+115, 5.88016193e+115, 5.90776832e+115,
#        5.93537471e+115, 5.96298111e+115, 5.99058750e+115, 6.01819390e+115,
#        6.04580029e+115, 6.07340668e+115, 6.10101308e+115, 6.12861947e+115,
#        6.15622587e+115, 6.18383226e+115, 6.21143865e+115, 6.23904505e+115,
#        6.26665144e+115, 6.29425784e+115, 6.32186423e+115, 6.34947062e+115,
#        6.37707702e+115, 6.40468341e+115, 6.43228981e+115, 6.45989620e+115,
#        6.48750259e+115, 6.51510899e+115, 6.54271538e+115, 6.57032178e+115,
#        6.59792817e+115, 6.62553456e+115, 6.65314096e+115, 6.68074735e+115,
#        6.70835375e+115, 6.73596014e+115, 6.76356653e+115, 6.79117293e+115,
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

data = [[2,0,81], [4,4,93], [6,2,91], [8,3,97]]
x1 = [i[0] for i in data]
x2 = [i[0] for i in data]
y = [i[2] for i in data]

ax = plt.axes(projection = "3d")
ax.set_xlabel("student_hours")
ax.set_ylabel("private_class")
ax.set_zlabel("score")
ax.dist = 11
ax.scatter (x1,x2,y)
plt.show()
# Out:
# C:\Users\juno\AppData\Local\Temp\ipykernel_24852\2932459855.py:14: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 11

# %%
x1_data = np.array(x1)
x2_data = np.array(x2)
y_data = np.array(y)

a1 = 0
a2 = 0
b = 0

lr = 0.02

epochs = 2023

for i in range(epochs):
    y_pred = a1 * x1_data + a2 * x2_data + b
    error = y_data - y_pred
    a1_diff = -(2/len(x1_data)) * sum(x1_data, (error))
    a2_diff = -(2/len(x2_data)) * sum(x2_data, (error))
    b_new = -(2/len(x1_data)) * sum(y_data, y_pred)
    a1 = a1 - lr * a1_diff
    a2 = a2 - lr * a2_diff
    b = b - lr * b_new 
    if i % 100 == 0:
        print("epochs :" ,i, "기울기 : " , a1,"기울기2",a2,"절편",b)
# Out:
# epochs : 0 기울기 :  [1.01 1.13 1.11 1.17] 기울기2 [1.01 1.13 1.11 1.17] 절편 [3.62 3.62 3.62 3.62]
# epochs : 100 기울기 :  [-74.69138494 -42.71592357 -29.43010827 -22.32377852] 기울기2 [-74.69138494 -42.71592357 -29.43010827 -22.32377852] 절편 [542.32138494 522.46592357 507.16010827 506.11377852]
# epochs : 200 기울기 :  [-225.28557192 -110.5561344   -72.43        -54.25711111] 기울기2 [-225.28557192 -110.5561344   -72.43        -54.25711111] 절편 [1155.91557192 1065.3061344  1023.16       1017.04711111]
# epochs : 300 기울기 :  [-379.44109947 -178.41326531 -115.43        -86.19044444] 기울기2 [-379.44109947 -178.41326531 -115.43        -86.19044444] 절편 [1773.07109947 1608.16326531 1539.16       1527.98044444]
# epochs : 400 기울기 :  [-533.76597769 -246.27040816 -158.43       -118.12377778] 기울기2 [-533.76597769 -246.27040816 -158.43       -118.12377778] 절편 [2390.39597769 2151.02040816 2055.16       2038.91377778]
# ...

# %%
pred_list = []
def pred(x_1,x_2):
    y = 1.58 * x_1 + 16.19 * x_2 * -2.5692
    pred_list.append(y)
    
for i in   range(4):
    x_1 = data[i][0]
    x_2 = data[i][1]
    pred(x_1, x_2)

# %%
pred_list
# Out:
# [3.16, -160.061392, -73.710696, -112.14604400000002]
